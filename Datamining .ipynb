# %%
from googleapiclient.discovery import build 
import googleapiclient
import os 
import pandas as pd

# %%
comments = []
DATA = pd.DataFrame(columns=["Name","Comment","Time","VideoId"])

# %%
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "" #Don't steal my dev key pls

youtube = googleapiclient.discovery.build(
        api_service_name, api_version, developerKey = DEVELOPER_KEY)
data = []
def get_comments(channelID):
    request = youtube.commentThreads().list(
        textFormat = "plainText",
        part = "snippet,replies",
        allThreadsRelatedToChannelId = channelID,
        maxResults = 100,
        #pageToken = token
    )

    response = request.execute()
    #data = []
    
    while len(data) < 1000000:
    
        token = response["nextPageToken"]
        #print(response['nextPageToken'])
        for item in response['items']:

            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            video = item['snippet']['topLevelComment']['snippet']['videoId']
            name = item['snippet']['topLevelComment']['snippet']['authorDisplayName']
            time = item['snippet']['topLevelComment']['snippet']['publishedAt']

            data.append([name, comment, time, video])

        if 'nextPageToken' in response:
            response = youtube.commentThreads().list(
                    textFormat = "plainText",
                    part = "snippet,replies",
                    allThreadsRelatedToChannelId = channelID,
                    maxResults = 100,
                    pageToken = response["nextPageToken"]
                ).execute()
        else:
            break
  

    return data

# %%
#get_comments("UCA7pNe41ML4IyGd5ohWMmAg")
comments = get_comments("UCnQC_G5Xsjhp9fEJKuIcrSw") #Ben shapiro
#comments = get_comments("UCzUV5283-l5c0oKRtyenj6Q")  #Mike Dice ----- Conspiracy Theory
#comments = get_comments("UCXIJgqnII2ZOINSWNOGFThA")  #Fox News
#comments = get_comments("UCIveFvW-ARp_B_RckhweNJw")  #Steven Crowder
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Input In [241], in <cell line: 2>()
#       1 #get_comments("UCA7pNe41ML4IyGd5ohWMmAg")
# ----> 2 comments = get_comments("UCnQC_G5Xsjhp9fEJKuIcrSw")
#
# Input In [240], in get_comments(channelID)
#      33     data.append([name, comment, time, video])
#      35 if 'nextPageToken' in response:
# ---> 36     response = youtube.commentThreads().list(
#      37             textFormat = "plainText",
#      38             part = "snippet,replies",
#      39             allThreadsRelatedToChannelId = channelID,
#      40             maxResults = 100,
#      41             pageToken = response["nextPageToken"]
#      42         ).execute()
#      43 else:
#      44     break
#
# ...

# %%
test = pd.DataFrame(data,columns=["Name","Comment","Time","VideoId"])
test = test.drop_duplicates()
print(data)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#frames = (DATA, test)
#DATA = pd.concat(frames)
DATA = test

# %%
DATA = DATA.drop_duplicates()
DATA
# Out:
#                       Name                                            Comment  \
# 0         S.M.R Swasey TRD  I think for one of the very few times I would ...
# 1              johnjohnson  man created religion because man needed religi...
# 2           Victor Bergman  Why are you betraying Trump like this? You sho...
# 3              Mike Toombs  Anyone notice these freaks are universally una...
# 4        Brian Plankenhorn       At what point is this considered pedophilia?
# ...                    ...                                                ...
# 881503  fredrik samuelssin                                   about time ben!!
# 881504           droogie76                             Their end game is now.
# 881505       George Edward  Taiwan is toast now that Beijing Biden is in t...
# 881506       Brian Pereira  Yes until china decouples with them and hangs ...
# 881507    Kimberly Mendoza  It’s like they do this sick thing for populari...
#
# ...

# %%
DATA.to_excel("Ben_Shapiro_1,000,000.xlsx", engine='xlsxwriter')
# with pd.ExcelWriter('Ben_Shapiro.xlsx', mode='a') as writer:  
#      DATA.to_excel(DATA, sheet_name='DATA')

# %%
Data_Ben = DATA
Data_Ben
# Out:
#                       Name                                            Comment  \
# 0         S.M.R Swasey TRD  I think for one of the very few times I would ...
# 1              johnjohnson  man created religion because man needed religi...
# 2           Victor Bergman  Why are you betraying Trump like this? You sho...
# 3              Mike Toombs  Anyone notice these freaks are universally una...
# 4        Brian Plankenhorn       At what point is this considered pedophilia?
# ...                    ...                                                ...
# 881503  fredrik samuelssin                                   about time ben!!
# 881504           droogie76                             Their end game is now.
# 881505       George Edward  Taiwan is toast now that Beijing Biden is in t...
# 881506       Brian Pereira  Yes until china decouples with them and hangs ...
# 881507    Kimberly Mendoza  It’s like they do this sick thing for populari...
#
# ...

# %%
Data_Mike
# Out:
#                      Name                                            Comment  \
# 0            ㄒɇȼħ Sɇɍ۷ٱƈﻉ                         he took out half the trash
# 1              Racer X777  What's up all these black NFL football players...
# 2              Rocky Road  The bird watch notification should be a clown ...
# 3       Robert Mroziewicz  Dreadlocks are not party of any culture as peo...
# 4                mr halvi  It's kind of like the NFL 90% white, sure wish...
# ...                   ...                                                ...
# 100033       Brenda Coale                                                🤢🤮🥵
# 100034       shane oldham  SACK THESE SICK MEN   AND TAKE THEM TO COURT  ...
# 100035               DOJI  No one can have a personal opinion these days ...
# 100036             btm380      Jordan Peele is half black.\nJust like Barry.
# 100037     Pamela Painter  The saying “It’s ok to be be white” just came ...
#
#                         Time      VideoId
# ...

# %%
Data_Fox
# Out:
#                    Name                                            Comment  \
# 0                  Kyle  My money is on more riots.\n\nWhen liberals th...
# 1           Blue Turtle  Someone needs to explain to me, in earnest, wh...
# 2               Jacob P  Which dem was it again that said minorities co...
# 3         EXPOSING EVIL  So sick of hearing these news outlets refer to...
# 4             R. Rogers                      Britney Spears is my goddess.
# ...                 ...                                                ...
# 100055    Peter Scheuer  We all know now the Ophara will back a complet...
# 100056     Lamar Carter  Out of all of this insanity I would give anyth...
# 100057      Fred Bagley  You know what the cool kids are doing? They ar...
# 100058       Rachel Mai  Shut up corrupted lies Hilary you destroying o...
# 100059  Jackie Sheahart  Lori Lightfoot loves to be the bright lights! ...
#
#                         Time      VideoId
# ...

# %%
Data_Steven
# Out:
#                        Name  \
# 0                 Richard G
# 1          Johnathon Walker
# 2          Johnathon Walker
# 3                 Semira954
# 4                 NotTux YT
# ...                     ...
# 100045          Hugh Manguy
# 100046  Trinity River Fence
# 100047       Evgeni Ptolemy
# 100048         Gino Vasquez
# 100049                gnamp
#
#                                                   Comment  \
# 0       Funny how these “activists” turn into pussies ...
# 1                                                F-U CCP!
# 2       Bring  Steven Crowder back! Youtube get your s...
# 3       No freedom of speech in Germany and i live in ...
# 4       Bro i hate videos like this people are so rude...
# ...                                                   ...
# 100045  Has this one episode taken away respect and cr...
# 100046                                               😂😂😂😂
# 100047  Honestly, the first time I saw Cancel Culture ...
# ...

# %%
count = 0
for name in Data_Steven["Name"]:
    
    if name in Data_Ben:
        print(name)
        count += 1
print(count)
# Out:
# Name
# 1

# %%
# Out:
# Empty DataFrame
# Columns: [Name, Comment, Time, VideoId]
# Index: []

# %%
Data_Ben = pd.read_excel("Ben_Shapiro_800,000.xlsx")
Data_Ben
# Out:
#         Unnamed: 0                Name  \
# 0                0    S.M.R Swasey TRD
# 1                1         johnjohnson
# 2                2      Victor Bergman
# 3                3         Mike Toombs
# 4                4   Brian Plankenhorn
# ...            ...                 ...
# 881471      881503  fredrik samuelssin
# 881472      881504           droogie76
# 881473      881505       George Edward
# 881474      881506       Brian Pereira
# 881475      881507    Kimberly Mendoza
#
#                                                   Comment  \
# 0       I think for one of the very few times I would ...
# 1       man created religion because man needed religi...
# 2       Why are you betraying Trump like this? You sho...
# 3       Anyone notice these freaks are universally una...
# 4            At what point is this considered pedophilia?
# ...                                                   ...
# 881471                                   about time ben!!
# ...

# %%
Data_Ben_Names = Data_Ben["Name"]
Data_Ben_Names.drop_duplicates()
Name_Count = []

# %%
for name in Data_Ben_Names:
    print(name)
# Out:
# S.M.R Swasey TRD
# johnjohnson
# Victor Bergman
# Mike Toombs
# Brian Plankenhorn
# Jorge Castillo
# Phantom 7 cross rose
# Jennifer Klopman
# Deano1948
# Aaron Edwards
# david ortiz
# Brian Gasser
# John
# 21jrmessi
# Kathleen Crepeau
# Adam Cheney
# JiWon
# kelvin b
# Dane Hoover
# Erik
# RWX Studio
# Natalie
# Demi Sutra
# Baow Schmeow
# Gavin Bautista
# Dee Kay
# Vira
# OBro
# Kevin 81
# Linda Ostrom
# Victor Bergman
# Jennie Hughes
# Cassie
# Damascus
# Terrance Sims
# O'Really
# Angela A
# Deify Samurai
# Isabella Garzon
# Live & Quality
# A Z
# origamipein18
# Gerald King
# Toy Mayhem
# Truth Seeker
# Clyde USA
# Phil Brodie
# Jackplays
# Lynk
# Misery MetallicaXperience
# H Mac
# Beate Müller
# Jason Hancock
# JMaddy
# trooper116
# Flybycommenter
# david ortiz
# Spaghetti Yeti
# J
# DanyTV
# Libby Rohrer
# Demi Sutra
# Jane kitenye
# Sah H
# jjm
# Kassandra Plante
# Louis Farkas
# Mary louise
# Professor Logos
# Josh 415
# nel6211
# Mia Moore
# ...

# %%
Data_Ben["Name"].value_counts()
# Out:
# John Smith                 517
# Michael                    446
# origamipein18              394
# Lightclaw Shadowmarsch     334
# yelnats von hindinbergh    333
#                           ...
# Mark Hughes                  1
# Phil Spann                   1
# So blub                      1
# Manuel Moran                 1
# Kimberly Mendoza             1
# Name: Name, Length: 353073, dtype: int64

# %%
Data_Ben[""]
